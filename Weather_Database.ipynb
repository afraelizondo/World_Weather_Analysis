# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 735

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f41c20ec5588cac19f795057501b97f8

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | aklavik
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | dalby
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | wamba
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | jamsa
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | ust-nera
# Processing Record 16 of Set 1 | waipawa
# Processing Record 17 of Set 1 | chokurdakh
# Processing Record 18 of Set 1 | khonsa
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | cayenne
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | grindavik
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | puerto princesa
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | bria
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | dafeng
# Processing Record 31 of Set 1 | lorengau
# Processing Record 32 of Set 1 | araouane
# Processing Record 33 of Set 1 | kirensk
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | zinder
# Processing Record 37 of Set 1 | caravelas
# Processing Record 38 of Set 1 | gorontalo
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | sinnamary
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | dogondoutchi
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | sartell
# Processing Record 4 of Set 2 | lockhart
# Processing Record 5 of Set 2 | nome
# Processing Record 6 of Set 2 | mandera
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | richards bay
# Processing Record 9 of Set 2 | kamenka
# Processing Record 10 of Set 2 | nantucket
# Processing Record 11 of Set 2 | mvangue
# Processing Record 12 of Set 2 | hambantota
# Processing Record 13 of Set 2 | san borja
# Processing Record 14 of Set 2 | orange
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | kuhdasht
# Processing Record 18 of Set 2 | pangnirtung
# Processing Record 19 of Set 2 | port-gentil
# Processing Record 20 of Set 2 | layou
# Processing Record 21 of Set 2 | hasaki
# Processing Record 22 of Set 2 | wahiawa
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | opuwo
# Processing Record 26 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | portland
# Processing Record 28 of Set 2 | constitucion
# Processing Record 29 of Set 2 | zhigalovo
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | port lincoln
# Processing Record 32 of Set 2 | mobaye
# Processing Record 33 of Set 2 | fairbanks
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | sitka
# Processing Record 38 of Set 2 | sumbawanga
# Processing Record 39 of Set 2 | bengkulu
# Processing Record 40 of Set 2 | druzhba
# Processing Record 41 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 2 | dingle
# Processing Record 43 of Set 2 | awjilah
# Processing Record 44 of Set 2 | cancun
# Processing Record 45 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 2 | souillac
# Processing Record 47 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | cockburn town
# Processing Record 50 of Set 2 | paamiut
# Processing Record 1 of Set 3 | dunedin
# Processing Record 2 of Set 3 | narasannapeta
# Processing Record 3 of Set 3 | warmbad
# Processing Record 4 of Set 3 | road town
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | nong bua
# Processing Record 8 of Set 3 | rudbar
# Processing Record 9 of Set 3 | butaritari
# Processing Record 10 of Set 3 | anadyr
# Processing Record 11 of Set 3 | port alfred
# Processing Record 12 of Set 3 | severobaykalsk
# Processing Record 13 of Set 3 | puerto narino
# Processing Record 14 of Set 3 | astana
# Processing Record 15 of Set 3 | rubizhne
# Processing Record 16 of Set 3 | hermanus
# Processing Record 17 of Set 3 | sao filipe
# Processing Record 18 of Set 3 | alekseyevka
# Processing Record 19 of Set 3 | esperance
# Processing Record 20 of Set 3 | yellowknife
# Processing Record 21 of Set 3 | ribeira grande
# Processing Record 22 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 3 | klyuchi
# Processing Record 24 of Set 3 | vitimskiy
# City not found. Skipping...
# Processing Record 25 of Set 3 | leningradskiy
# Processing Record 26 of Set 3 | airai
# Processing Record 27 of Set 3 | gambela
# Processing Record 28 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 3 | sola
# Processing Record 30 of Set 3 | atasu
# Processing Record 31 of Set 3 | port blair
# Processing Record 32 of Set 3 | svetlogorsk
# Processing Record 33 of Set 3 | alice springs
# Processing Record 34 of Set 3 | morros
# Processing Record 35 of Set 3 | kavieng
# Processing Record 36 of Set 3 | adelanto
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | mananara
# Processing Record 39 of Set 3 | hobyo
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | cabo san lucas
# Processing Record 42 of Set 3 | marsa matruh
# Processing Record 43 of Set 3 | vestmanna
# Processing Record 44 of Set 3 | seddon
# Processing Record 45 of Set 3 | khorixas
# Processing Record 46 of Set 3 | cape town
# Processing Record 47 of Set 3 | durban
# Processing Record 48 of Set 3 | berlevag
# Processing Record 49 of Set 3 | gizo
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | ampanihy
# Processing Record 2 of Set 4 | bratsk
# Processing Record 3 of Set 4 | bialogard
# Processing Record 4 of Set 4 | manta
# Processing Record 5 of Set 4 | east london
# Processing Record 6 of Set 4 | salalah
# Processing Record 7 of Set 4 | asyut
# Processing Record 8 of Set 4 | tampakan
# Processing Record 9 of Set 4 | olafsvik
# Processing Record 10 of Set 4 | ilulissat
# Processing Record 11 of Set 4 | san cristobal
# Processing Record 12 of Set 4 | orbetello
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | otradnoye
# Processing Record 15 of Set 4 | senanga
# Processing Record 16 of Set 4 | san patricio
# Processing Record 17 of Set 4 | arraial do cabo
# Processing Record 18 of Set 4 | adrar
# Processing Record 19 of Set 4 | saldanha
# Processing Record 20 of Set 4 | turukhansk
# Processing Record 21 of Set 4 | carnarvon
# Processing Record 22 of Set 4 | acarau
# Processing Record 23 of Set 4 | los llanos de aridane
# Processing Record 24 of Set 4 | carros
# Processing Record 25 of Set 4 | clyde river
# Processing Record 26 of Set 4 | nouadhibou
# Processing Record 27 of Set 4 | pacifica
# Processing Record 28 of Set 4 | severo-kurilsk
# Processing Record 29 of Set 4 | kangaatsiaq
# Processing Record 30 of Set 4 | edd
# Processing Record 31 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 4 | itarema
# Processing Record 34 of Set 4 | gwadar
# Processing Record 35 of Set 4 | matara
# Processing Record 36 of Set 4 | varhaug
# Processing Record 37 of Set 4 | alpena
# Processing Record 38 of Set 4 | sao felix do xingu
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | peniche
# Processing Record 41 of Set 4 | te anau
# Processing Record 42 of Set 4 | kiunga
# Processing Record 43 of Set 4 | ivanivka
# Processing Record 44 of Set 4 | shenjiamen
# Processing Record 45 of Set 4 | bageshwar
# Processing Record 46 of Set 4 | freeport
# Processing Record 47 of Set 4 | luwuk
# Processing Record 48 of Set 4 | sorong
# Processing Record 49 of Set 4 | forestville
# Processing Record 50 of Set 4 | shache
# Processing Record 1 of Set 5 | iqaluit
# Processing Record 2 of Set 5 | amambai
# Processing Record 3 of Set 5 | obersiggenthal
# Processing Record 4 of Set 5 | klaksvik
# Processing Record 5 of Set 5 | cherskiy
# Processing Record 6 of Set 5 | bubaque
# Processing Record 7 of Set 5 | oksfjord
# Processing Record 8 of Set 5 | longhua
# Processing Record 9 of Set 5 | westport
# Processing Record 10 of Set 5 | mizpe ramon
# City not found. Skipping...
# Processing Record 11 of Set 5 | burica
# City not found. Skipping...
# Processing Record 12 of Set 5 | lethem
# Processing Record 13 of Set 5 | torbay
# Processing Record 14 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 5 | maningrida
# Processing Record 16 of Set 5 | krasnyy chikoy
# Processing Record 17 of Set 5 | tijucas
# Processing Record 18 of Set 5 | luderitz
# Processing Record 19 of Set 5 | luba
# Processing Record 20 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 5 | solnechnyy
# Processing Record 22 of Set 5 | fortuna
# Processing Record 23 of Set 5 | comodoro rivadavia
# Processing Record 24 of Set 5 | witu
# Processing Record 25 of Set 5 | yaan
# Processing Record 26 of Set 5 | iwanai
# Processing Record 27 of Set 5 | gourcy
# Processing Record 28 of Set 5 | sault sainte marie
# Processing Record 29 of Set 5 | seydi
# Processing Record 30 of Set 5 | mehamn
# Processing Record 31 of Set 5 | katsuura
# Processing Record 32 of Set 5 | kulhudhuffushi
# Processing Record 33 of Set 5 | khuzhir
# Processing Record 34 of Set 5 | ouro preto
# Processing Record 35 of Set 5 | nemuro
# Processing Record 36 of Set 5 | skibbereen
# Processing Record 37 of Set 5 | gaoual
# Processing Record 38 of Set 5 | necochea
# Processing Record 39 of Set 5 | noumea
# Processing Record 40 of Set 5 | flinders
# Processing Record 41 of Set 5 | udachnyy
# Processing Record 42 of Set 5 | henties bay
# Processing Record 43 of Set 5 | quatre cocos
# Processing Record 44 of Set 5 | saskylakh
# Processing Record 45 of Set 5 | kedougou
# Processing Record 46 of Set 5 | pulandian
# Processing Record 47 of Set 5 | xuanhua
# Processing Record 48 of Set 5 | ulagan
# Processing Record 49 of Set 5 | hualmay
# Processing Record 50 of Set 5 | mecca
# Processing Record 1 of Set 6 | aitape
# Processing Record 2 of Set 6 | waingapu
# Processing Record 3 of Set 6 | springbok
# Processing Record 4 of Set 6 | taft
# Processing Record 5 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 6 of Set 6 | redmond
# Processing Record 7 of Set 6 | kindu
# Processing Record 8 of Set 6 | taburao
# City not found. Skipping...
# Processing Record 9 of Set 6 | srednekolymsk
# Processing Record 10 of Set 6 | pueblo nuevo
# Processing Record 11 of Set 6 | lensk
# Processing Record 12 of Set 6 | qasigiannguit
# Processing Record 13 of Set 6 | pontianak
# Processing Record 14 of Set 6 | bira
# Processing Record 15 of Set 6 | kaiwaka
# Processing Record 16 of Set 6 | kita
# Processing Record 17 of Set 6 | chikoy
# City not found. Skipping...
# Processing Record 18 of Set 6 | verkhoturye
# Processing Record 19 of Set 6 | puerto baquerizo moreno
# Processing Record 20 of Set 6 | kambar
# Processing Record 21 of Set 6 | naze
# Processing Record 22 of Set 6 | emet
# Processing Record 23 of Set 6 | cidreira
# Processing Record 24 of Set 6 | kudahuvadhoo
# Processing Record 25 of Set 6 | fos-sur-mer
# Processing Record 26 of Set 6 | southbury
# Processing Record 27 of Set 6 | jeremie
# Processing Record 28 of Set 6 | magistralnyy
# Processing Record 29 of Set 6 | vinukonda
# Processing Record 30 of Set 6 | amarante
# Processing Record 31 of Set 6 | ternate
# Processing Record 32 of Set 6 | avera
# Processing Record 33 of Set 6 | coihaique
# Processing Record 34 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 6 | beringovskiy
# Processing Record 36 of Set 6 | lavrentiya
# Processing Record 37 of Set 6 | killybegs
# Processing Record 38 of Set 6 | hofn
# Processing Record 39 of Set 6 | menongue
# Processing Record 40 of Set 6 | kieta
# Processing Record 41 of Set 6 | deputatskiy
# Processing Record 42 of Set 6 | mubi
# Processing Record 43 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 6 | gisborne
# Processing Record 45 of Set 6 | mount isa
# Processing Record 46 of Set 6 | laguna
# Processing Record 47 of Set 6 | xuddur
# Processing Record 48 of Set 6 | faanui
# Processing Record 49 of Set 6 | bialystok
# Processing Record 50 of Set 6 | rincon
# Processing Record 1 of Set 7 | roma
# Processing Record 2 of Set 7 | muroto
# Processing Record 3 of Set 7 | velingrad
# Processing Record 4 of Set 7 | trenggalek
# Processing Record 5 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 7 | kaitangata
# Processing Record 7 of Set 7 | longyearbyen
# Processing Record 8 of Set 7 | vardo
# Processing Record 9 of Set 7 | lianzhou
# Processing Record 10 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 7 | aanekoski
# Processing Record 12 of Set 7 | tura
# Processing Record 13 of Set 7 | emporia
# Processing Record 14 of Set 7 | winneba
# Processing Record 15 of Set 7 | arman
# Processing Record 16 of Set 7 | consolacion del sur
# Processing Record 17 of Set 7 | quito
# Processing Record 18 of Set 7 | norman wells
# Processing Record 19 of Set 7 | ware
# Processing Record 20 of Set 7 | stromness
# Processing Record 21 of Set 7 | takoradi
# Processing Record 22 of Set 7 | agde
# Processing Record 23 of Set 7 | saint-louis
# Processing Record 24 of Set 7 | buin
# Processing Record 25 of Set 7 | bambous virieux
# Processing Record 26 of Set 7 | lumeje
# Processing Record 27 of Set 7 | kununurra
# Processing Record 28 of Set 7 | nata
# Processing Record 29 of Set 7 | sal rei
# Processing Record 30 of Set 7 | madaoua
# Processing Record 31 of Set 7 | touros
# Processing Record 32 of Set 7 | gdov
# Processing Record 33 of Set 7 | bam
# Processing Record 34 of Set 7 | yarmouth
# Processing Record 35 of Set 7 | coahuayana
# Processing Record 36 of Set 7 | north bend
# Processing Record 37 of Set 7 | koupela
# Processing Record 38 of Set 7 | amapa
# Processing Record 39 of Set 7 | ihosy
# Processing Record 40 of Set 7 | porto santo
# Processing Record 41 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 7 | carolina
# Processing Record 43 of Set 7 | tevaitoa
# Processing Record 44 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 7 | palmares do sul
# Processing Record 47 of Set 7 | buala
# Processing Record 48 of Set 7 | ambulu
# Processing Record 49 of Set 7 | sao joao da barra
# Processing Record 50 of Set 7 | jalu
# Processing Record 1 of Set 8 | tayoltita
# Processing Record 2 of Set 8 | hvide sande
# Processing Record 3 of Set 8 | alofi
# Processing Record 4 of Set 8 | benghazi
# Processing Record 5 of Set 8 | esna
# Processing Record 6 of Set 8 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 7 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 8 | linjiang
# Processing Record 9 of Set 8 | mayo
# Processing Record 10 of Set 8 | itoman
# Processing Record 11 of Set 8 | hattingen
# Processing Record 12 of Set 8 | kahului
# Processing Record 13 of Set 8 | saint-pierre
# Processing Record 14 of Set 8 | vanimo
# Processing Record 15 of Set 8 | jerome
# Processing Record 16 of Set 8 | jambi
# Processing Record 17 of Set 8 | camacupa
# Processing Record 18 of Set 8 | bari
# Processing Record 19 of Set 8 | murashi
# Processing Record 20 of Set 8 | vila velha
# Processing Record 21 of Set 8 | dongsheng
# Processing Record 22 of Set 8 | rio cuarto
# Processing Record 23 of Set 8 | irbil
# Processing Record 24 of Set 8 | erdenet
# Processing Record 25 of Set 8 | kathu
# Processing Record 26 of Set 8 | shamsabad
# Processing Record 27 of Set 8 | znamenskoye
# Processing Record 28 of Set 8 | lander
# Processing Record 29 of Set 8 | catamarca
# Processing Record 30 of Set 8 | kozhva
# Processing Record 31 of Set 8 | sisimiut
# Processing Record 32 of Set 8 | manaure
# Processing Record 33 of Set 8 | andenes
# Processing Record 34 of Set 8 | saint george
# Processing Record 35 of Set 8 | zhoukou
# Processing Record 36 of Set 8 | bathsheba
# Processing Record 37 of Set 8 | russkaya polyana
# Processing Record 38 of Set 8 | labuhan
# Processing Record 39 of Set 8 | mali
# Processing Record 40 of Set 8 | coos bay
# Processing Record 41 of Set 8 | gilazi
# City not found. Skipping...
# Processing Record 42 of Set 8 | kochki
# Processing Record 43 of Set 8 | maceio
# Processing Record 44 of Set 8 | rocha
# Processing Record 45 of Set 8 | geraldton
# Processing Record 46 of Set 8 | namatanai
# Processing Record 47 of Set 8 | benemerito de las americas
# Processing Record 48 of Set 8 | bodden town
# Processing Record 49 of Set 8 | brae
# Processing Record 50 of Set 8 | martapura
# Processing Record 1 of Set 9 | manaus
# Processing Record 2 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 9 | alekseyevsk
# Processing Record 4 of Set 9 | harlingen
# Processing Record 5 of Set 9 | port hardy
# Processing Record 6 of Set 9 | hovd
# Processing Record 7 of Set 9 | hendijan
# City not found. Skipping...
# Processing Record 8 of Set 9 | cururupu
# Processing Record 9 of Set 9 | matay
# Processing Record 10 of Set 9 | ancud
# Processing Record 11 of Set 9 | yulara
# Processing Record 12 of Set 9 | inhambane
# Processing Record 13 of Set 9 | namibe
# Processing Record 14 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 15 of Set 9 | aljezur
# Processing Record 16 of Set 9 | ketchikan
# Processing Record 17 of Set 9 | narsaq
# Processing Record 18 of Set 9 | merauke
# Processing Record 19 of Set 9 | bilibino
# Processing Record 20 of Set 9 | kemijarvi
# Processing Record 21 of Set 9 | minsk
# Processing Record 22 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 23 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 24 of Set 9 | senlis
# Processing Record 25 of Set 9 | lagos
# Processing Record 26 of Set 9 | gananoque
# Processing Record 27 of Set 9 | black river
# Processing Record 28 of Set 9 | saint-georges
# Processing Record 29 of Set 9 | jega
# Processing Record 30 of Set 9 | nuuk
# Processing Record 31 of Set 9 | coffs harbour
# Processing Record 32 of Set 9 | zhifang
# Processing Record 33 of Set 9 | makow mazowiecki
# Processing Record 34 of Set 9 | tabou
# Processing Record 35 of Set 9 | prnjavor
# Processing Record 36 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 38 of Set 9 | mumford
# Processing Record 39 of Set 9 | port hedland
# Processing Record 40 of Set 9 | kalemie
# Processing Record 41 of Set 9 | port macquarie
# Processing Record 42 of Set 9 | bogovarovo
# Processing Record 43 of Set 9 | den helder
# Processing Record 44 of Set 9 | toyooka
# Processing Record 45 of Set 9 | najran
# Processing Record 46 of Set 9 | mogadishu
# Processing Record 47 of Set 9 | hanna
# Processing Record 48 of Set 9 | beloha
# Processing Record 49 of Set 9 | panzhihua
# Processing Record 50 of Set 9 | codrington
# Processing Record 1 of Set 10 | tuatapere
# Processing Record 2 of Set 10 | klaeng
# Processing Record 3 of Set 10 | makurdi
# Processing Record 4 of Set 10 | hondo
# Processing Record 5 of Set 10 | pangkalanbuun
# Processing Record 6 of Set 10 | ayios nikolaos
# Processing Record 7 of Set 10 | harper
# Processing Record 8 of Set 10 | coquimbo
# Processing Record 9 of Set 10 | tahta
# Processing Record 10 of Set 10 | tianpeng
# Processing Record 11 of Set 10 | wagar
# Processing Record 12 of Set 10 | ko samui
# Processing Record 13 of Set 10 | laem sing
# Processing Record 14 of Set 10 | duminichi
# Processing Record 15 of Set 10 | charters towers
# Processing Record 16 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 10 | vestmannaeyjar
# Processing Record 19 of Set 10 | guerrero negro
# Processing Record 20 of Set 10 | sadiqabad
# Processing Record 21 of Set 10 | khash
# Processing Record 22 of Set 10 | chara
# Processing Record 23 of Set 10 | san pedro
# Processing Record 24 of Set 10 | lagoa
# Processing Record 25 of Set 10 | pisco
# Processing Record 26 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 10 | severo-yeniseyskiy
# Processing Record 28 of Set 10 | biloela
# Processing Record 29 of Set 10 | raul soares
# Processing Record 30 of Set 10 | neiafu
# Processing Record 31 of Set 10 | palasbari
# Processing Record 32 of Set 10 | kruisfontein
# Processing Record 33 of Set 10 | bandarbeyla
# Processing Record 34 of Set 10 | salimpur
# Processing Record 35 of Set 10 | lupeni
# Processing Record 36 of Set 10 | nouakchott
# Processing Record 37 of Set 10 | salinopolis
# Processing Record 38 of Set 10 | aiquile
# Processing Record 39 of Set 10 | camocim
# Processing Record 40 of Set 10 | laramie
# Processing Record 41 of Set 10 | north adams
# Processing Record 42 of Set 10 | turbiv
# Processing Record 43 of Set 10 | san rafael
# Processing Record 44 of Set 10 | makakilo city
# Processing Record 45 of Set 10 | mitsamiouli
# Processing Record 46 of Set 10 | sibiti
# Processing Record 47 of Set 10 | miles city
# Processing Record 48 of Set 10 | lompoc
# Processing Record 49 of Set 10 | sinfra
# Processing Record 50 of Set 10 | cay
# Processing Record 1 of Set 11 | saint-michel-des-saints
# Processing Record 2 of Set 11 | esperanza
# Processing Record 3 of Set 11 | nishihara
# Processing Record 4 of Set 11 | lahat
# Processing Record 5 of Set 11 | palmer
# Processing Record 6 of Set 11 | vao
# Processing Record 7 of Set 11 | hammerfest
# Processing Record 8 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 9 of Set 11 | diffa
# Processing Record 10 of Set 11 | esso
# Processing Record 11 of Set 11 | wanning
# Processing Record 12 of Set 11 | pervomayskiy
# Processing Record 13 of Set 11 | uberlandia
# Processing Record 14 of Set 11 | ferkessedougou
# Processing Record 15 of Set 11 | paramonga
# Processing Record 16 of Set 11 | acapulco
# Processing Record 17 of Set 11 | zonguldak
# Processing Record 18 of Set 11 | homer
# Processing Record 19 of Set 11 | kichmengskiy gorodok
# Processing Record 20 of Set 11 | staropyshminsk
# Processing Record 21 of Set 11 | eastlake
# Processing Record 22 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 11 | magdagachi
# Processing Record 24 of Set 11 | warrnambool
# Processing Record 25 of Set 11 | edson
# Processing Record 26 of Set 11 | altay
# Processing Record 27 of Set 11 | college
# Processing Record 28 of Set 11 | egvekinot
# Processing Record 29 of Set 11 | sibolga
# Processing Record 30 of Set 11 | taganak
# Processing Record 31 of Set 11 | kano
# Processing Record 32 of Set 11 | saint-joseph
# Processing Record 33 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 11 | agadez
# Processing Record 35 of Set 11 | sangar
# Processing Record 36 of Set 11 | bandar-e lengeh
# Processing Record 37 of Set 11 | bonthe
# Processing Record 38 of Set 11 | sandata
# Processing Record 39 of Set 11 | jatai
# Processing Record 40 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 41 of Set 11 | porto novo
# Processing Record 42 of Set 11 | lakselv
# Processing Record 43 of Set 11 | morehead
# Processing Record 44 of Set 11 | whitianga
# Processing Record 45 of Set 11 | half moon bay
# Processing Record 46 of Set 11 | grand gaube
# Processing Record 47 of Set 11 | huilong
# Processing Record 48 of Set 11 | ambovombe
# Processing Record 49 of Set 11 | gorlice
# Processing Record 50 of Set 11 | oktyabrskiy
# Processing Record 1 of Set 12 | bacolod
# Processing Record 2 of Set 12 | issenye
# Processing Record 3 of Set 12 | verkhoyansk
# Processing Record 4 of Set 12 | nyagan
# Processing Record 5 of Set 12 | calamar
# Processing Record 6 of Set 12 | shingu
# Processing Record 7 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 12 | conakry
# Processing Record 9 of Set 12 | pinotepa nacional
# Processing Record 10 of Set 12 | santa luzia
# Processing Record 11 of Set 12 | kutum
# Processing Record 12 of Set 12 | labrea
# Processing Record 13 of Set 12 | cochrane
# Processing Record 14 of Set 12 | mount gambier
# Processing Record 15 of Set 12 | yakeshi
# Processing Record 16 of Set 12 | irece
# Processing Record 17 of Set 12 | tilichiki
# Processing Record 18 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 12 | arica
# Processing Record 20 of Set 12 | cascais
# Processing Record 21 of Set 12 | semey
# Processing Record 22 of Set 12 | tautira
# Processing Record 23 of Set 12 | moose factory
# Processing Record 24 of Set 12 | leninskoye
# Processing Record 25 of Set 12 | wairoa
# Processing Record 26 of Set 12 | marana
# Processing Record 27 of Set 12 | karpogory
# Processing Record 28 of Set 12 | allentown
# Processing Record 29 of Set 12 | bayburt
# Processing Record 30 of Set 12 | dudinka
# Processing Record 31 of Set 12 | anchorage
# Processing Record 32 of Set 12 | seoul
# Processing Record 33 of Set 12 | fairview
# Processing Record 34 of Set 12 | houma
# Processing Record 35 of Set 12 | gao
# Processing Record 36 of Set 12 | sao gabriel da cachoeira
# Processing Record 37 of Set 12 | saint anthony
# Processing Record 38 of Set 12 | panaba
# Processing Record 39 of Set 12 | marystown
# Processing Record 40 of Set 12 | tingloy
# Processing Record 41 of Set 12 | walvis bay
# Processing Record 42 of Set 12 | debre birhan
# Processing Record 43 of Set 12 | price
# Processing Record 44 of Set 12 | murray bridge
# Processing Record 45 of Set 12 | monterotondo
# Processing Record 46 of Set 12 | moussoro
# Processing Record 47 of Set 12 | the valley
# Processing Record 48 of Set 12 | tateyama
# Processing Record 49 of Set 12 | corn island
# Processing Record 50 of Set 12 | cassilandia
# Processing Record 1 of Set 13 | juneau
# Processing Record 2 of Set 13 | yuxia
# Processing Record 3 of Set 13 | lom sak
# Processing Record 4 of Set 13 | houston
# Processing Record 5 of Set 13 | nanae
# Processing Record 6 of Set 13 | batagay
# Processing Record 7 of Set 13 | mahanje
# Processing Record 8 of Set 13 | malanje
# Processing Record 9 of Set 13 | lar
# Processing Record 10 of Set 13 | mtimbira
# Processing Record 11 of Set 13 | shahdadkot
# Processing Record 12 of Set 13 | octeville
# Processing Record 13 of Set 13 | ciudad bolivar
# Processing Record 14 of Set 13 | pokhara
# Processing Record 15 of Set 13 | talcahuano
# Processing Record 16 of Set 13 | shihezi
# Processing Record 17 of Set 13 | sioux lookout
# Processing Record 18 of Set 13 | fastovetskaya
# Processing Record 19 of Set 13 | tonj
# Processing Record 20 of Set 13 | tomatlan
# Processing Record 21 of Set 13 | belaya gora
# Processing Record 22 of Set 13 | riyadh
# Processing Record 23 of Set 13 | ust-karsk
# Processing Record 24 of Set 13 | la ronge
# Processing Record 25 of Set 13 | hit
# Processing Record 26 of Set 13 | margate
# Processing Record 27 of Set 13 | gongzhuling
# Processing Record 28 of Set 13 | gigmoto
# Processing Record 29 of Set 13 | vaitape
# Processing Record 30 of Set 13 | chulman
# Processing Record 31 of Set 13 | adre
# Processing Record 32 of Set 13 | dubbo
# Processing Record 33 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 34 of Set 13 | hamilton
# Processing Record 35 of Set 13 | talnakh
# Processing Record 36 of Set 13 | cabedelo
# Processing Record 37 of Set 13 | bilma
# Processing Record 38 of Set 13 | goderich
# Processing Record 39 of Set 13 | vila franca do campo
# Processing Record 40 of Set 13 | yelizovo
# Processing Record 41 of Set 13 | fukue
# Processing Record 42 of Set 13 | ramat yishay
# Processing Record 43 of Set 13 | san quintin
# Processing Record 44 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 45 of Set 13 | tara
# Processing Record 46 of Set 13 | oriximina
# Processing Record 47 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 13 | kalmunai
# Processing Record 49 of Set 13 | broome
# Processing Record 50 of Set 13 | purificacion
# Processing Record 1 of Set 14 | oytal
# Processing Record 2 of Set 14 | odweyne
# Processing Record 3 of Set 14 | sampit
# Processing Record 4 of Set 14 | fallon
# Processing Record 5 of Set 14 | sakaiminato
# Processing Record 6 of Set 14 | asau
# Processing Record 7 of Set 14 | nabire
# Processing Record 8 of Set 14 | zanjan
# Processing Record 9 of Set 14 | nara
# Processing Record 10 of Set 14 | mazagao
# Processing Record 11 of Set 14 | sakakah
# Processing Record 12 of Set 14 | broken hill
# Processing Record 13 of Set 14 | kota
# Processing Record 14 of Set 14 | carutapera
# Processing Record 15 of Set 14 | fayaoue
# Processing Record 16 of Set 14 | khandyga
# Processing Record 17 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 19 of Set 14 | kimbe
# Processing Record 20 of Set 14 | kure
# Processing Record 21 of Set 14 | zeya
# Processing Record 22 of Set 14 | senador jose porfirio
# Processing Record 23 of Set 14 | selty
# Processing Record 24 of Set 14 | kurilsk
# Processing Record 25 of Set 14 | muros
# Processing Record 26 of Set 14 | san vicente
# Processing Record 27 of Set 14 | rawson
# Processing Record 28 of Set 14 | stornoway
# Processing Record 29 of Set 14 | thunder bay
# Processing Record 30 of Set 14 | moron
# Processing Record 31 of Set 14 | kenai
# Processing Record 32 of Set 14 | saint-augustin
# Processing Record 33 of Set 14 | ustyuzhna
# Processing Record 34 of Set 14 | soyo
# Processing Record 35 of Set 14 | west wendover
# Processing Record 36 of Set 14 | auki
# Processing Record 37 of Set 14 | ribeira brava
# Processing Record 38 of Set 14 | la asuncion
# Processing Record 39 of Set 14 | bumba
# Processing Record 40 of Set 14 | hami
# Processing Record 41 of Set 14 | sur
# Processing Record 42 of Set 14 | novyy urgal
# Processing Record 43 of Set 14 | usinsk
# Processing Record 44 of Set 14 | byron bay
# Processing Record 45 of Set 14 | castanos
# Processing Record 46 of Set 14 | evensk
# Processing Record 47 of Set 14 | manbij
# Processing Record 48 of Set 14 | vokhtoga
# Processing Record 49 of Set 14 | uyuni
# Processing Record 50 of Set 14 | rantepao
# Processing Record 1 of Set 15 | cap malheureux
# Processing Record 2 of Set 15 | antalaha
# Processing Record 3 of Set 15 | bowmore
# Processing Record 4 of Set 15 | pingliang
# Processing Record 5 of Set 15 | oldenburg
# Processing Record 6 of Set 15 | santa cruz
# Processing Record 7 of Set 15 | severodvinsk
# Processing Record 8 of Set 15 | biltine
# Processing Record 9 of Set 15 | oistins
# Processing Record 10 of Set 15 | leshan
# Processing Record 11 of Set 15 | saint-henri-de-levis
# City not found. Skipping...
# Processing Record 12 of Set 15 | dali
# Processing Record 13 of Set 15 | changping
# Processing Record 14 of Set 15 | nueva san salvador
# City not found. Skipping...
# Processing Record 15 of Set 15 | uray
# Processing Record 16 of Set 15 | meulaboh
# Processing Record 17 of Set 15 | santa rosa
# Processing Record 18 of Set 15 | faya
# Processing Record 19 of Set 15 | oussouye
# Processing Record 20 of Set 15 | cao bang
# Processing Record 21 of Set 15 | frankfort
# Processing Record 22 of Set 15 | puerto carreno
# Processing Record 23 of Set 15 | santiago
# Processing Record 24 of Set 15 | dzhebariki-khaya
# Processing Record 25 of Set 15 | safaga
# Processing Record 26 of Set 15 | komsomolskiy
# Processing Record 27 of Set 15 | gat
# Processing Record 28 of Set 15 | taltal
# Processing Record 29 of Set 15 | san carlos de bariloche
# Processing Record 30 of Set 15 | mollendo
# Processing Record 31 of Set 15 | sao miguel do araguaia
# Processing Record 32 of Set 15 | aasiaat
# Processing Record 33 of Set 15 | kankan
# Processing Record 34 of Set 15 | abnub
# Processing Record 35 of Set 15 | isangel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 682

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Atuona  -9.8000 -139.0333     78.40        74          76
# 1    Bredasdorp -34.5322   20.0403     55.26        74         100
# 2   Tuktoyaktuk  69.4541 -133.0374     21.20        86          75
# 3    Georgetown   5.4112  100.3354     85.95        81          20
# 4       Aklavik  68.2191 -135.0107     10.92        80          49
# 5  Ponta Do Sol  32.6667  -17.1000     68.72        77          22
# 6     Hithadhoo  -0.6000   73.0833     81.32        75          11
# 7       Mataura -46.1927  168.8643     58.48        71          95
# 8         Dalby -27.1833  151.2667     78.31        15           0
# 9         Wamba   8.9333    8.6000     70.32        36          61
#
#    Wind Speed Country       Description
# 0       15.73      PF     broken clouds
# 1        2.66      ZA   overcast clouds
# 2        4.61      CA     broken clouds
# 3        0.00      MY        few clouds
# 4        6.71      CA  scattered clouds
# 5        7.92      PT        few clouds
# 6       14.07      MV        few clouds
# 7        1.70      NZ   overcast clouds
# 8        7.43      AU         clear sky
# 9        3.83      NG     broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                    Atuona      PF  -9.8000 -139.0333     78.40        74
# 1                Bredasdorp      ZA -34.5322   20.0403     55.26        74
# 2               Tuktoyaktuk      CA  69.4541 -133.0374     21.20        86
# 3                Georgetown      MY   5.4112  100.3354     85.95        81
# 4                   Aklavik      CA  68.2191 -135.0107     10.92        80
# ..                      ...     ...      ...       ...       ...       ...
# 677  Sao Miguel Do Araguaia      BR -13.2750  -50.1628     76.80        64
# 678                 Aasiaat      GL  68.7098  -52.8699     13.30        96
# 679                  Kankan      GN  10.3854   -9.3057     68.83        34
# 680                   Abnub      EG  27.2696   31.1511     57.42        59
# 681                 Isangel      VU -19.5500  169.2667     87.91        66
#
#      Cloudiness  Wind Speed       Description
# 0            76       15.73     broken clouds
# 1           100        2.66   overcast clouds
# 2            75        4.61     broken clouds
# 3            20        0.00        few clouds
# 4            49        6.71  scattered clouds
# ..          ...         ...               ...
# 677          15        4.21        few clouds
# 678         100        5.01   overcast clouds
# 679         100        2.75   overcast clouds
# 680           0        3.00         clear sky
# 681          75        4.61     broken clouds
#
# [682 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
